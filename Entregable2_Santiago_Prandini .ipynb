# %% [markdown]
# ##Entregable 2 - Santiago Prandini
#
# Consigna: El script de la entrega 1 deberá adaptar datos leídos de la API y cargarlos en la tabla creada en la pre-entrega anterior en Redshift

# %%
#importamos las librerías que vamos a utilizar en el trabajo
import requests
import json
import pandas as pd

import os
from configparser import ConfigParser

from pathlib import Path
import sqlalchemy as sa

config = ConfigParser()

# %%
#nos conectamos con la carpeta drive donde se van a alojar los datos de la API correspondientes a client_id y key
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#establecemos la dirección de la carpeta donde estamos conectados
base_dir = "/content/drive/MyDrive"

# %%
#cambiamos al directorio actual
os.chdir(base_dir)

# %%
#establecemos la dirección del archivo de configuracion
config_dir = "config/config.ini"

#leemos el archivo
config.read(config_dir)
# Out:
# ['config/config.ini']

# %%
#chequeamos que esté trayendo lso datos del archivo de configuración
config["credenciales_api"]["client_id"]
# Out:
# 'e774f99f-7557-40a2-8a09-558a292e6755'

# %%
#definimos la variable client_id tomando los datos del archivo del drive de nombre config
client_id = config["credenciales_api"]["client_id"]

# %%
#definimos la variable client_secret tomando los datos del archivo del drive de nombre config
client_secret = config["credenciales_api"]["client_key"]

# %%
# Armamos la url con el endpoint y especificando las credenciales como parámetros. Se utiliza la API de la NASA, y el endpoint que devuelve eventos naturales, se le pasa como status el estado open ya que interesan los eventes que están aconteciendo en la actualidad
url_base = "https://eonet.gsfc.nasa.gov"
endpoint = "api/v2.1/events"

url = f"{url_base}/{endpoint}?status=open&client_id={client_id}&client_secret={client_secret}"

# %%
# Obtenemos datos haciendo un GET usando el método get de la librería
resp = requests.get(url)

# %%
#consultamos el status de la consulta
if resp.status_code == 200:
  resp_json = resp.json()
else:
  print(resp.status_code, resp.content)

# %%
#observamos los resultados obtenidos
print(resp_json)
# Out:
# {'title': 'EONET Events', 'description': 'Natural events from EONET.', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events', 'events': [{'id': 'EONET_6451', 'title': 'Tropical Cyclone Mal', 'description': '', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_6451', 'categories': [{'id': 10, 'title': 'Severe Storms'}], 'sources': [{'id': 'EO', 'url': 'https://earthobservatory.nasa.gov/images/151989/hurricane-otis'}, {'id': 'JTWC', 'url': 'https://www.metoc.navy.mil/jtwc/products/sh0224.tcw'}], 'geometries': [{'date': '2023-11-13T00:00:00Z', 'type': 'Point', 'coordinates': [170.8, -9.6]}, {'date': '2023-11-13T06:00:00Z', 'type': 'Point', 'coordinates': [171.8, -11.1]}, {'date': '2023-11-13T12:00:00Z', 'type': 'Point', 'coordinates': [173.2, -12.5]}, {'date': '2023-11-13T18:00:00Z', 'type': 'Point', 'coordinates': [174, -13.5]}, {'date': '2023-11-14T00:00:00Z', 'type': 'Point', 'coordinates': [174.7, -14.7]}, {'date': '2023-11-14T06:00:00Z', 'type': 'Point', 'coordinates': [175.1, -16.1]}, {'date': '2023-11-14T12:00:00Z', 'type': 'Point', 'coordinates': [175.6, -17.2]}]}, {'id': 'EONET_6450', 'title': 'Wvnrp Steep Valley Fire Information', 'description': '', 'link': 'https://eonet.gsfc.nasa.gov/api/v2.1/events/EONET_6450', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 
# %%
#creamos un dataframe para ver los resultados obtenidos
df = pd.DataFrame(resp_json['events'])

# %%
#observamos el dataframe
df
# Out:
#              id                                title description  \
# 0    EONET_6451                 Tropical Cyclone Mal
# 1    EONET_6450  Wvnrp Steep Valley Fire Information
# 2    EONET_6449                  Ioto Volcano, Japan
# 3    EONET_6448                          Iceberg D34
# 4    EONET_6440                      Hurricane Tammy
# ..          ...                                  ...         ...
# 391  EONET_2876                          Iceberg C15
# 392  EONET_2878                         Iceberg B09B
# 393  EONET_2879                         Iceberg D20A
# 394  EONET_2997                         Iceberg C21B
# 395   EONET_980             Fuego Volcano, Guatemala
#
#                                                   link  \
# 0    https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 1    https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 2    https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 3    https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 4    https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# ..                                                 ...
# 391  https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 392  https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 393  https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 394  https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
# 395  https://eonet.gsfc.nasa.gov/api/v2.1/events/EO...
#
#                                     categories  \
# 0       [{'id': 10, 'title': 'Severe Storms'}]
# 1            [{'id': 8, 'title': 'Wildfires'}]
# 2           [{'id': 12, 'title': 'Volcanoes'}]
# 3    [{'id': 15, 'title': 'Sea and Lake Ice'}]
# 4       [{'id': 10, 'title': 'Severe Storms'}]
# ..                                         ...
# 391  [{'id': 15, 'title': 'Sea and Lake Ice'}]
# 392  [{'id': 15, 'title': 'Sea and Lake Ice'}]
# 393  [{'id': 15, 'title': 'Sea and Lake Ice'}]
# 394  [{'id': 15, 'title': 'Sea and Lake Ice'}]
# 395         [{'id': 12, 'title': 'Volcanoes'}]
#
#                                                sources  \
# 0    [{'id': 'EO', 'url': 'https://earthobservatory...
# 1    [{'id': 'InciWeb', 'url': 'http://inciweb.nwcg...
# 2    [{'id': 'SIVolcano', 'url': 'https://volcano.s...
# 3    [{'id': 'NATICE', 'url': 'https://usicecenter....
# 4    [{'id': 'GDACS', 'url': 'http://www.gdacs.org/...
# ..                                                 ...
# 391  [{'id': 'BYU_ICE', 'url': 'http://www.scp.byu....
# 392  [{'id': 'BYU_ICE', 'url': 'http://www.scp.byu....
# 393  [{'id': 'BYU_ICE', 'url': 'http://www.scp.byu....
# 394  [{'id': 'BYU_ICE', 'url': 'http://www.scp.byu....
# 395  [{'id': 'CEMS', 'url': 'http://emergency.coper...
#
#                                             geometries
# 0    [{'date': '2023-11-13T00:00:00Z', 'type': 'Poi...
# 1    [{'date': '2023-11-06T19:00:00Z', 'type': 'Poi...
# 2    [{'date': '2023-10-30T00:00:00Z', 'type': 'Poi...
# 3    [{'date': '2023-10-20T00:00:00Z', 'type': 'Poi...
# 4    [{'date': '2023-10-18T21:00:00Z', 'type': 'Poi...
# ..                                                 ...
# 391  [{'date': '2011-08-30T00:00:00Z', 'type': 'Poi...
# 392  [{'date': '2011-08-30T00:00:00Z', 'type': 'Poi...
# 393  [{'date': '2011-08-30T00:00:00Z', 'type': 'Poi...
# 394  [{'date': '2011-08-30T00:00:00Z', 'type': 'Poi...
# 395  [{'date': '2002-01-04T00:00:00Z', 'type': 'Poi...
#
# [396 rows x 7 columns]

# %%
#consultamos la columnas para crear la tabla en Redshift
df.columns
# Out:
# Index(['id', 'title', 'description', 'link', 'categories', 'sources',
#        'geometries'],
#       dtype='object')

# %%
#instalamos el conector a redshift
# %pip install "redshift_connector[full]" sqlalchemy-redshift
# Out:
# Requirement already satisfied: redshift_connector[full] in /usr/local/lib/python3.10/dist-packages (2.0.916)
# Requirement already satisfied: sqlalchemy-redshift in /usr/local/lib/python3.10/dist-packages (0.8.14)
# Requirement already satisfied: scramp<1.5.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (2023.3.post1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (4.11.2)
# Requirement already satisfied: boto3<2.0.0,>=1.9.201 in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (1.28.85)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (2.31.0)
# Requirement already satisfied: lxml>=4.6.5 in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (4.9.3)
# Requirement already satisfied: botocore<2.0.0,>=1.12.201 in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (1.31.85)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (23.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from redshift_connector[full]) (1.5.3)
# Requirement already satisfied: SQLAlchemy<2.0.0,>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy-redshift) (1.4.50)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.7.0->redshift_connector[full]) (2.5)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0.0,>=1.9.201->redshift_connector[full]) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0.0,>=1.9.201->redshift_connector[full]) (0.7.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<2.0.0,>=1.12.201->redshift_connector[full]) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<2.0.0,>=1.12.201->redshift_connector[full]) (2.0.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->redshift_connector[full]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->redshift_connector[full]) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->redshift_connector[full]) (2023.7.22)
# Requirement already satisfied: asn1crypto>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from scramp<1.5.0,>=1.2.0->redshift_connector[full]) (1.5.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<2.0.0,>=0.9.2->sqlalchemy-redshift) (3.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.12.201->redshift_connector[full]) (1.16.0)

# %%
#creamos una función que arme la cadena de conexión a la base de datos a partir del archivo de configuracion

def build_conn_string(config_path, config_section):

    # Lee el archivo de configuración
    parser = ConfigParser()
    parser.read(config_path)

    # Lee la sección de configuración de PostgreSQL
    config = parser[config_section]
    host = config['host']
    port = config['port']
    dbname = config['dbname']
    username = config['username']
    pwd = config['pwd']

    # Construye la cadena de conexión
    conn_string = f'postgresql://{username}:{pwd}@{host}:{port}/{dbname}?sslmode=require'

    return conn_string

# %%
#creamos una función que cree la conexión a la base de datos
def connect_to_db(conn_string):

    engine = sa.create_engine(conn_string)
    conn = engine.connect()
    return conn, engine

# %%
#nos conectamos a la base de datos
conn_str = build_conn_string("/content/drive/MyDrive/config/config.ini", "redshift")

# %%
conn, engine = connect_to_db(conn_str)

# %%
#definimos el esquema y creamos la tabla en redshift para guardar los datos que trae la API. Definimos que si ya existe la tabla la elimine
schema = "santiprandini_coderhouse"

conn.execute(
    f"""
        DROP TABLE IF EXISTS {schema}.eventos_actuales;
        CREATE TABLE {schema}.eventos_actuales (
            id VARCHAR PRIMARY KEY,
            title VARCHAR,
            description VARCHAR,
            link VARCHAR


        );
    """
)

# %%
#eliminamos las columnas que vienen en formato JSON
columns_to_drop = ['categories', 'sources', 'geometries']
df = df.drop(columns=columns_to_drop)

# %%
#cargamos los datos obtenidos de la API en la base de datos de Redshift
df.to_sql(
    name="eventos_actuales",
    con=conn,
    schema=schema,
    if_exists="replace",
    method="multi",
    index=False,
    )
# Out:
# 396

# %%
# Opcion para cargar solo registros que no existen en la tabla
df.to_sql(
    name="eventos_actuales",
    con=conn,
    schema=schema,
    if_exists="append",
    index=False,
    method="multi",
    chunksize=1000,

)
# Out:
# 396
